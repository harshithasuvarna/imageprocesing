# %%
import numpy as np
import cv2 
img = np.zeros((400, 400, 3), dtype = "uint8")
cv2.imshow('dark.jpg', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
img = np.zeros((400, 400, 3), dtype = "uint8")
  

cv2.rectangle(img, (30, 30), (300, 200), (0, 255, 0), 5)
  
cv2.imshow('dark', img)
  

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
  

img = np.zeros((400, 400, 3), dtype = "uint8")
  

cv2.circle(img, (200, 200), 80, (255, 0, 0), 3)
  
cv2.imshow('dark', img)
  

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#restore a damage image
import numpy as np
import cv2
  
# Open the image.
img = cv2.imread('cat_damaged.png')
  
# Load the mask.
mask = cv2.imread('cat_mask.png', 0)
  
# Inpaint.
dst = cv2.inpaint(img, mask, 3, cv2.INPAINT_NS)
  
# Write the output.
cv2.imwrite('cat_inpainted.png', dst)
# Out:
# True

# %%
#adding noise
import matplotlib.pyplot as plt
from skimage.util import random_noise
nature_image=plt.imread('fruits.jpg')
noisy_image=random_noise(nature_image)
plt.title('Original image')
plt.imshow(nature_image)
plt.show()
plt.title('Noisy image')
plt.imshow(noisy_image)
plt.show()

# %%
#reducing noise
import matplotlib.pyplot as plt
from skimage.restoration import denoise_tv_chambolle
noisy_image=plt.imread('images.jpg')
denoised_image=denoise_tv_chambolle(noisy_image,multichannel=True)
plt.title('Noisy image')
plt.imshow(noisy_image)
plt.show()
plt.title('Clear image')
plt.imshow(denoised_image)
plt.show()

# %%
#preserving noise
import matplotlib.pyplot as plt
from skimage.restoration import denoise_bilateral
landscape_image=plt.imread('cat.jpg')
denoised_image=denoise_bilateral(landscape_image,multichannel=True)
plt.title('Noisy image')
plt.imshow(landscape_image)
plt.show()
plt.title('Denoised image')
plt.imshow(denoised_image)
plt.show()
