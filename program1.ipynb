# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread,imshow
image1=imread('img.jpg')
imshow(image1);

# %%
image2=imread('jumbo.jpg',as_gray=True)
imshow(image2);

# %%
print(image1.shape)
print(image2.shape)
# Out:
# (1920, 2560, 3)
# (216, 288)

# %%
print(image1.size)
print(image2.size)
# Out:
# 14745600
# 62208

# %%
pixel_features1 = np.reshape(image2,(216*288))
pixel_features1.shape,pixel_features1
# Out:
# ((62208,),
#  array([0.21102235, 0.17375608, 0.18326588, ..., 0.82662392, 0.78347882,
#         0.73446275]))

# %%
pixel_features2 = np.reshape(image1,(1920*2560*3))
pixel_features1.shape,pixel_features2
# Out:
# ((62208,), array([ 40,  47,  55, ..., 184, 223, 116], dtype=uint8))

# %%
from PIL import Image,ImageStat
im=Image.open('jumbo.jpg')
stat=ImageStat.Stat(im)
print(stat.var)
# Out:
# [3711.8675575209186, 4287.307574506354, 2441.666665409766]
